# %% [markdown]
# <a href="https://colab.research.google.com/github/fralfaro/CodingDojo-DataScience/blob/main/docs/12-SQL/12-SQL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# # SQL Alchemy
#
# ## Introducción
#
# <img src="https://www.vitoshacademy.com/wp-content/uploads/2015/05/sqlalchemy-logo1.png">

# %% [markdown]
# - Biblioteca creada como interfaz de conexión entre el lenguaje Python y bases de datos relacionales SQL.
# - Esta interfaz tiene un alto grado de compatibilidad con la biblioteca pandas.
# - Soporta múltiples motores de base de datos, tales como SQLite, Postgresql, MySQL, Oracle, MS-SQL, Firebird, Sybase, etc.
# -  Si está trabajando en su entorno local, previo a su importación debe ser **instalada**
#     - ```pip install sqlalchemy``` si usa ```pip```
#     - ```conda install sqlalchemy``` si usa ```conda```

# %%
from sqlalchemy import create_engine
import pandas as pd

# %%
import logging

logging.disable(logging.WARNING)

# %%
# create sqlite engine
engine = create_engine('sqlite:///school.db', echo=True)
# create connection to engine
conn = engine.connect()

# %%
# add the dataframe as a table in sqlite
sqlite_table = "school_details"
school = pd.read_csv('https://raw.githubusercontent.com/fralfaro/CodingDojo-DataScience/main/docs/12-SQL/data/School%20Details.csv')
school.to_sql(sqlite_table, conn, if_exists='replace')

sqlite_table2 = "school_facility_details"
facility = pd.read_csv('https://raw.githubusercontent.com/fralfaro/CodingDojo-DataScience/main/docs/12-SQL/data/School%20Facility%20Details.csv')
facility.to_sql(sqlite_table2, conn, if_exists='replace')
# Out:
# 1256

# %%
# Se utiliza la variable de conexión con el motor para realizar queries SQL sobre la base de datos
query = '''
SELECT * FROM school_details
'''

df = pd.read_sql_query(query, engine)

df.head()
# Out:
#    index DistrictName EstablishmentCode  \
# 0      0         East             S0169
# 1      1         East             S0099
# 2      2         East             S0848
# 3      3         East             S0190
# 4      4         East             S0111
#
#                                    EstablishmentName   BRCName  \
# 0               BUDANG GOVERNMENT PRIMARY SCHOOL (E)  Duga Brc
# 1  CENTRAL PENDAM GOVERNMENT SENIOR SECONDARY SCHOOL  Duga Brc
# 2              CENTRAL POINT ACADEMY, CENTRAL PENDAM  Duga Brc
# 3      CHEURIBOTEY GOVERNMENT JUNIOR HIGH SCHOOL (E)  Duga Brc
# 4                   DUGA GOVERNMENT SECONDARY SCHOOL  Duga Brc
#
#                                              CRCName SchoolLevel  \
# 0  Central Pendam Government Senior Secondary School          PS
# 1  Central Pendam Government Senior Secondary School         SSS
# 2  Central Pendam Government Senior Secondary School          SS
# 3  Central Pendam Government Senior Secondary School         JHS
# 4  Central Pendam Government Senior Secondary School          SS
#
#       ManagementName            LocalityHabitation SubdivisionName  ...  \
# 0        State Govt.                        BUDANG         Gangtok  ...
# 1        State Govt.                CENTRAL PENDAM         Gangtok  ...
# 2  Private (Unaided)  UPPER BHURUNG CENTRAL PENDAM         Gangtok  ...
# 3        State Govt.                   CHEURIBOTEY         Gangtok  ...
# 4        State Govt.                          DUGA         Gangtok  ...
#
#      EstablishedDate DistrictHQDistance (in Km) CRCDistance (in Km)  \
# 0              28126                       58.0                 8.0
# 1              15342                       50.0                 0.0
# 2  37257.38680555556                       49.0                 1.5
# 3              28856                       60.0                 6.0
# 4               1828                       52.0                 0.0
#
#   BACDistance (in Km) IsRecognized           RecognizedBy ContactPersonName  \
# 0                16.0   Recognized                   HRDD              None
# 1                 6.0   Recognized                   HRDD              None
# 2                 6.0   Recognized  HRDD, GOVT. OF SIKKIM              None
# 3                 6.0   Recognized            State Govt.              None
# 4                 0.5   Recognized               c.b.s.e.              None
#
#   LowestClass HighestClass BoardName
# 0     Class 1      Class 5      None
# 1     Class 1     Class 12  C.B.S.E.
# 2     Class 1     Class 10  C.B.S.E.
# 3     Class 1      Class 8      None
# 4     Class 1     Class 10  C.B.S.E.
#
# [5 rows x 31 columns]

# %% [markdown]
# ## Problemas Básicos

# %% [markdown]
# * Mostrar las primeras 5 filas de la tabla `school_details`.

# %%
query = '''
SELECT * FROM school_details
LIMIT 5
'''
df = pd.read_sql_query(query, engine)
df
# Out:
#    index DistrictName EstablishmentCode  \
# 0      0         East             S0169
# 1      1         East             S0099
# 2      2         East             S0848
# 3      3         East             S0190
# 4      4         East             S0111
#
#                                    EstablishmentName   BRCName  \
# 0               BUDANG GOVERNMENT PRIMARY SCHOOL (E)  Duga Brc
# 1  CENTRAL PENDAM GOVERNMENT SENIOR SECONDARY SCHOOL  Duga Brc
# 2              CENTRAL POINT ACADEMY, CENTRAL PENDAM  Duga Brc
# 3      CHEURIBOTEY GOVERNMENT JUNIOR HIGH SCHOOL (E)  Duga Brc
# 4                   DUGA GOVERNMENT SECONDARY SCHOOL  Duga Brc
#
#                                              CRCName SchoolLevel  \
# 0  Central Pendam Government Senior Secondary School          PS
# 1  Central Pendam Government Senior Secondary School         SSS
# 2  Central Pendam Government Senior Secondary School          SS
# 3  Central Pendam Government Senior Secondary School         JHS
# 4  Central Pendam Government Senior Secondary School          SS
#
#       ManagementName            LocalityHabitation SubdivisionName  ...  \
# 0        State Govt.                        BUDANG         Gangtok  ...
# 1        State Govt.                CENTRAL PENDAM         Gangtok  ...
# 2  Private (Unaided)  UPPER BHURUNG CENTRAL PENDAM         Gangtok  ...
# 3        State Govt.                   CHEURIBOTEY         Gangtok  ...
# 4        State Govt.                          DUGA         Gangtok  ...
#
#      EstablishedDate DistrictHQDistance (in Km) CRCDistance (in Km)  \
# 0              28126                       58.0                 8.0
# 1              15342                       50.0                 0.0
# 2  37257.38680555556                       49.0                 1.5
# 3              28856                       60.0                 6.0
# 4               1828                       52.0                 0.0
#
#   BACDistance (in Km) IsRecognized           RecognizedBy ContactPersonName  \
# 0                16.0   Recognized                   HRDD              None
# 1                 6.0   Recognized                   HRDD              None
# 2                 6.0   Recognized  HRDD, GOVT. OF SIKKIM              None
# 3                 6.0   Recognized            State Govt.              None
# 4                 0.5   Recognized               c.b.s.e.              None
#
#   LowestClass HighestClass BoardName
# 0     Class 1      Class 5      None
# 1     Class 1     Class 12  C.B.S.E.
# 2     Class 1     Class 10  C.B.S.E.
# 3     Class 1      Class 8      None
# 4     Class 1     Class 10  C.B.S.E.
#
# [5 rows x 31 columns]

# %% [markdown]
# * Seleccionar los valores únicos de la columna `DistrictName` de la tabla `school_details`.

# %%
query = '''
SELECT DISTINCT(DistrictName) FROM school_details
'''
df = pd.read_sql_query(query, engine)
df
# Out:
#   DistrictName
# 0         East
# 1        North
# 2        South
# 3         West

# %% [markdown]
# * Seleccionar y cambiar el nombre de la columna `EstablishmentCode` por `ECode` de la tabla `school_details`.

# %%
query = '''
SELECT EstablishmentCode AS ECode FROM school_details
'''
df = pd.read_sql_query(query, engine)
df
# Out:
#       ECode
# 0     S0169
# 1     S0099
# 2     S0848
# 3     S0190
# 4     S0111
# ...     ...
# 1244  S0336
# 1245  S0591
# 1246  S1045
# 1247  S0340
# 1248  S0542
#
# [1249 rows x 1 columns]

# %% [markdown]
# * Filtrar el conjunto de datos la columna `SchoolLevel` por `PS` de la tabla `school_details`.

# %%
query = '''
SELECT * FROM school_details
WHERE SchoolLevel = 'PS'
'''
df = pd.read_sql_query(query, engine)
df.head()
# Out:
#    index DistrictName EstablishmentCode                     EstablishmentName  \
# 0      0         East             S0169  BUDANG GOVERNMENT PRIMARY SCHOOL (E)
# 1      5         East             S0856      EASWARAMMA SAI GURUKOOL ACCADEMY
# 2      6         East             S0870   ETERNAL ENGLISH SCHOOL, WEST PENDAM
# 3      7         East             S0157  KHANI GOAN GOVERNMENT PRIMARY SCHOOL
# 4      8         East             S0876   NEW GARDEN BOARDING SCHOOL (SAJONG)
#
#     BRCName                                            CRCName SchoolLevel  \
# 0  Duga Brc  Central Pendam Government Senior Secondary School          PS
# 1  Duga Brc  Central Pendam Government Senior Secondary School          PS
# 2  Duga Brc  Central Pendam Government Senior Secondary School          PS
# 3  Duga Brc  Central Pendam Government Senior Secondary School          PS
# 4  Duga Brc  Central Pendam Government Senior Secondary School          PS
#
#       ManagementName LocalityHabitation SubdivisionName  ...  \
# 0        State Govt.             BUDANG         Gangtok  ...
# 1  Private (Unaided)             RALUNG         Gangtok  ...
# 2  Private (Unaided)  SAKHU WEST PENDAM         Gangtok  ...
# 3        State Govt.        WEST PENDAM         Gangtok  ...
# 4  Private (Unaided)     CENTRAL PENDAM         Gangtok  ...
#
#      EstablishedDate DistrictHQDistance (in Km) CRCDistance (in Km)  \
# 0              28126                       58.0                 8.0
# 1  40179.66805555556                        0.0                 0.2
# 2  37300.66805555556                       42.0                 3.0
# 3              29587                       45.0                 5.0
# 4  33604.66805555556                       40.0                 7.0
#
#   BACDistance (in Km)    IsRecognized    RecognizedBy ContactPersonName  \
# 0                16.0      Recognized            HRDD              None
# 1                 0.2      Recognized            None              None
# 2                 4.0      Recognized  HRDD OF SIKKIM              None
# 3                 4.0      Recognized     State Govt.              None
# 4                 7.0  Not Recognized            None              None
#
#   LowestClass HighestClass BoardName
# 0     Class 1      Class 5      None
# 1     Class 1      Class 5      None
# 2     Class 1      Class 5      None
# 3     Class 1      Class 5  C.B.S.E.
# 4     Class 1      Class 4      None
#
# [5 rows x 31 columns]

# %% [markdown]
# ## Problemas Avanzados

# %% [markdown]
# * ¿Cuál es la distancia BAC promedio (en Km)? Cambie el nombre de la columna de salida a "avg_bac distancia".

# %%
# Write your SQL query in this string
sql = """
SELECT AVG("BACDistance (in Km)") AS avg_bac_distance
FROM school_details
"""

# Read the sql query into pandas to view the results
df = pd.read_sql_query(sql, engine)
df.head()
# Out:
#    avg_bac_distance
# 0         12.681822

# %% [markdown]
# * ¿Cuál es la distancia BAC promedio (en Km) por nivel escolar? Ordene los resultados del promedio más alto al promedio más bajo.

# %%
# Write your SQL query in this string
sql = """
SELECT SchoolLevel, AVG("BACDistance (in Km)") as avg_bac_distance
FROM school_details
GROUP BY SchoolLevel
ORDER BY avg_bac_distance DESC
"""

# Read the sql query into pandas to view the results
df = pd.read_sql_query(sql, engine)
df.head()
# Out:
#   SchoolLevel  avg_bac_distance
# 0         JHS         13.692647
# 1          PS         12.830787
# 2          SS         12.630872
# 3         SSS         10.863095
# 4         LPS          5.368421

# %% [markdown]
# * Repita la consulta anterior, pero solo muestre resultados donde la distancia promedio sea de al menos 10 km.

# %%
# Write your SQL query in this string
sql = """
SELECT SchoolLevel, AVG("BACDistance (in Km)") as avg_bac_distance
FROM school_details
GROUP BY SchoolLevel
HAVING avg_bac_distance >= 10
ORDER BY avg_bac_distance DESC
"""

# Read the sql query into pandas to view the results
df = pd.read_sql_query(sql, engine)
df.head()
# Out:
#   SchoolLevel  avg_bac_distance
# 0         JHS         13.692647
# 1          PS         12.830787
# 2          SS         12.630872
# 3         SSS         10.863095

# %% [markdown]
# * Une las dos tablas juntas (school_details y school_facility_details). Comience mostrando todas las columnas, pero limite las filas resultantes a solo 2.

# %%
# Write your SQL query in this string
sql = """
SELECT *
FROM school_details s
  JOIN school_facility_details f
  ON f.EstablishmentCode = s.EstablishmentCode
LIMIT 2
"""

# Read the sql query into pandas to view the results
df = pd.read_sql_query(sql, engine)
df.head()
# Out:
#    index DistrictName EstablishmentCode  \
# 0      0         East             S0169
# 1      1         East             S0099
#
#                                    EstablishmentName   BRCName  \
# 0               BUDANG GOVERNMENT PRIMARY SCHOOL (E)  Duga Brc
# 1  CENTRAL PENDAM GOVERNMENT SENIOR SECONDARY SCHOOL  Duga Brc
#
#                                              CRCName SchoolLevel  \
# 0  Central Pendam Government Senior Secondary School          PS
# 1  Central Pendam Government Senior Secondary School         SSS
#
#   ManagementName LocalityHabitation SubdivisionName  ...  \
# 0    State Govt.             BUDANG         Gangtok  ...
# 1    State Govt.     CENTRAL PENDAM         Gangtok  ...
#
#                                    EstablishmentName IsLibraryAvailable  \
# 0               BUDANG GOVERNMENT PRIMARY SCHOOL (E)          Available
# 1  CENTRAL PENDAM GOVERNMENT SENIOR SECONDARY SCHOOL          Available
#
#   AvailableBooksCount IsFireExtgAvailable ExtinguisherCount HOIRoomAvailable  \
# 0                 100           Available                 2        Available
# 1                   0           Available                 5        Available
#
#   IsStaffRoomAvailable NoofStaffRoom IsLockerForStaffAvailable  \
# 0            Available             1             Not Available
# 1            Available             2             Not Available
#
#   IsSportsStoreRoomAvailable
# 0              Not Available
# 1                  Available
#
# [2 rows x 43 columns]

# %% [markdown]
# * Ahora, seleccione solo las escuelas donde SchoolLevel es "PS" que no tienen bibliotecas.

# %%
# Write your SQL query in this string
sql = """
SELECT s.EstablishmentName, s.SchoolLevel, f.IsLibraryAvailable
FROM school_details s
  JOIN school_facility_details f
  ON f.EstablishmentCode = s.EstablishmentCode
WHERE s.SchoolLevel = 'PS' AND f.IsLibraryAvailable = 'Not Available'
"""

# Read the sql query into pandas to view the results
df = pd.read_sql_query(sql, engine)
df.head()
# Out:
#                         EstablishmentName SchoolLevel IsLibraryAvailable
# 0        EASWARAMMA SAI GURUKOOL ACCADEMY          PS      Not Available
# 1     NEW GARDEN BOARDING SCHOOL (SAJONG)          PS      Not Available
# 2     SARASWATI SHISHU VIDHYALAYA, BUDANG          PS      Not Available
# 3        SAWNEY GOVERNMENT PRIMARY SCHOOL          PS      Not Available
# 4  UPPER PACHAK GOVERNMENT PRIMARY SCHOOL          PS      Not Available

# %% [markdown]
# * Construya a partir de la consulta anterior, pero ordene los resultados alfabéticamente por nombre.

# %%
# Write your SQL query in this string
sql = """
SELECT s.EstablishmentName, s.SchoolLevel, f.IsLibraryAvailable
FROM school_details s
  JOIN school_facility_details f
  ON f.EstablishmentCode = s.EstablishmentCode
WHERE s.SchoolLevel = 'PS' AND f.IsLibraryAvailable = 'Not Available'
ORDER BY s.EstablishmentName
"""

# Read the sql query into pandas to view the results
df = pd.read_sql_query(sql, engine)
df.head()
# Out:
#                                    EstablishmentName SchoolLevel  \
# 0  (I.E.C) INDIAN EVANGALISTIC CRUSADE MISSION PR...          PS
# 1                10TH MILE GOVERNMENT PRIMARY SCHOOL          PS
# 2                  AAPGAZI GOVERNMENT PRIMARY SCHOOL          PS
# 3                AARUBOTEY GOVERNMENT PRIMARY SCHOOL          PS
# 4              AHO-YANGTAM GOVERNMENT PRIMARY SCHOOL          PS
#
#   IsLibraryAvailable
# 0      Not Available
# 1      Not Available
# 2      Not Available
# 3      Not Available
# 4      Not Available

# %%
# Close the database connection
conn.close()
